# %% [markdown]
# # Proejct 4: Web Scraping Job Posting
# Business Case Overview
#
# You're working as a data scientist for a contracting firm that's rapidly expanding. Now that they have their most valuable employee (you!), they need to leverage data to win more contracts. Your firm offers technology and scientific solutions and wants to be competitive in the hiring market. Your principal has two main objectives:
#
#
# 1. **Determine the industry factors that are most important in predicting the salary amounts for these data.**
# 2. **Determine the factors that distinguish job categories and titles from each other. For example, can required skills accurately predict job title?**
#
# To limit the scope, your principal has suggested that you focus on data-related job postings, e.g. **data scientist, data analyst, research scientist, business intelligence**, and any others you might think of. You may also want to decrease the scope by limiting your search to a **single region**.
#
# Hint: Aggregators like [Indeed.com](https://www.indeed.com.sg/?r=us) regularly pool job postings from a variety of markets and industries.
#
# Goal: Scrape your own data from a job aggregation tool like Indeed.com in order to collect the data to best answer these two questions.

# %% [markdown]
# ## Scraping data from Indeed
# Example website screencapture:
# ![image.png](attachment:image.png)

# %% [markdown]
# References:<br>
# [Web Scraping Indeed for Key Data Science Job Skills - Jesse Steinweg-Woods](https://jessesw.com/Data-Science-Skills/) <br>
# [Web Scraping Indeed.com to Predict Salaries - Nathan Mitchell](https://ntmitchell.github.io/indeed-jobs-postings/) <br>
# https://bigdata-madesimple.com/top-big-data-tools-used-to-store-and-analyse-data/

# %% [markdown]
# The scraping process mainly deal with the main search page, and the long process make it extremely difficult to access individual job posting. There also a challenge that the website access is not stable,make iterating very difficult.This error often poped up with no reason. Thus, individual search keywords were used.
# ![image.png](attachment:image.png)

# %%
#web scraping
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import requests

import re

import pandas as pd
import numpy as np

# %%
# #key words
# #job title keywords
# job_title=['data scientist', 'data analyst', 'data engineer','research scientist', 'business intelligence','analytics']

# #job types
# job_type=['permanent','fulltime','contract','temporary','internship','parttime','apprenticeship']

# %% [markdown]
# First look at the 1st page of the search results by searching data analyst in UK, with 50 results display per page: <br>
# https://www.indeed.co.uk/jobs?q=data+analyst&jt=permanent&limit=50<br> and open web development tool to inspect the webpage. <br>
# It seems that the Indeed UK webiste can only allow maximum to display 50 search result at one page, further increase of the number after limit does not actually increase the display results. <br>
#
# *The main focus* is on two job types: permanent and fulltime, as well as 6 positions: 'data scientist', 'data analyst', 'data engineer','research scientist', 'business intelligence','analytics

# %%
#test the function above 
#url: https://www.indeed.com/viewjob?jk=27162dddbf2459fa&from=serp&vjs=3
#website_cleaner('https://www.indeed.com/viewjob?jk=27162dddbf2459fa&from=serp&vjs=3')

# %%
#Start web scraping
#The main purpose is to extract as much as information as possible
#yet keep the information succinct 

def generate_search_df(position,types):

    result_df=pd.DataFrame()
    
    print ('Searching for ',position,'and','types')
    
    title='+'.join(position.split(' '))
    
    
    #initiate an empty list to collect data everytime for new position and job type
    result_list=[]

    print ('Under ',position,'search for ',types,' job')

    url='https://www.indeed.co.uk/jobs?q={}&jt={}&limit=50'.format(title,types)
    response = requests.get(url,headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'})
    first_page=BeautifulSoup(response.content,'html.parser')

    job_counts=(first_page.find("div", attrs = {"id": "searchCount"}).text.split(' '))[-1]

    #loop over the pages and viewing 100 results per page at a time
    i = int(int(job_counts.replace(',',''))/50)

    for page_number in range(i+1):
        print ('Accessing page ',page_number,'\n')

        url_each_page = 'https://www.indeed.co.uk/jobs?q={}&jt={}&limit=50&start={}'.format(position,types,(str(50*page_number)))
        response = requests.get(url_each_page,headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'})
        soup_each_page = BeautifulSoup(response.content,'html.parser')
        # Get all advertised job descriptions
        results = soup_each_page.find_all('div', attrs={'data-tn-component': 'organicJob'})

        #extract job ID for each job listing
        for x in results:
            job_id = x.find(name='h2', attrs={"class": "jobtitle"})['id']
            job_title = x.find('a', attrs={'data-tn-element': "jobTitle"})
            job_link = "https://www.indeed.com" + x.find('h2', attrs={"class": "jobtitle"}).find('a')['href']
            job_summary=x.find('span',{'class':'summary'})
            company=x.find(name='span', attrs={'class':'company'})
            location = x.find(name='span', attrs={'class':'location'})
            time_posted = x.find('span',{'class':'date'})
            salary = x.find(name='span', attrs={'class':'no-wrap'})


            #set default missing values
            if job_title != None:
                job_title_result = job_title.get_text().strip()
            else:
                job_title_result = np.nan

            if company != None:
                company_result = company.get_text().strip()
            else:
                company_result = np.nan

            if job_summary != None:
                job_summary_result = job_summary.get_text().strip()
            else:
                job_summary_result = np.nan

            if salary != None:
                salary_result = salary.get_text().strip()
            else:
                salary_result = np.nan

            if location != None:
                location_result = location.get_text().strip()
            else:
                location_result = np.nan

            if time_posted != None:
                time_posted_result = time_posted.get_text().strip()
            else:
                time_posted_result=np.nan

            for div in x.find_all(name='td',attrs={"class":"snip"}):
                try:
                    span = div.find(name="span", attrs={"class":"no-wrap"})
                    salary_result = span.get_text().strip()
                except:
                    salary_result = np.nan

            review = x.find('a', attrs={"class": "ratingsLabel"})
            if review != None:
                review_result = review.get_text().strip()
            else:
                review_result=np.nan


            result_list.append([job_id,types, title,time_posted_result, job_title_result, company_result, salary_result, 
                                location_result, review_result,
                                job_summary_result])
        result_df=result_df.append(result_list)
    result_df.drop_duplicates(inplace=True)
        
    result_df.columns = ['job_id','job_types','job_tag','post_time', 'job_title', 'company', 'salary', 
                                    'location', 'no_of_review','job_summary']
    
    #save list into csv file

    print ('It\'s done now! You can look at the output csv file.')
    print ('There are ',len(result_df),'jobs successfully extracted. ')
    result_df.to_csv('./{}.csv'.format(position + types))

    return result_df.head(2)

# %%
generate_search_df('data scientist','permanent')
# Out:
# Searching for  data scientist and types
# Under  data scientist search for  permanent  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# It's done now! You can look at the output csv file.
# There are  944 jobs successfully extracted.
#                   job_id  job_types         job_tag     post_time  \
# 0    jl_3becc778f10b2727  permanent  data+scientist   3 hours ago
# 1    jl_311f8c87f377fec1  permanent  data+scientist    9 days ago
# 2    jl_950a6428afc8792c  permanent  data+scientist   10 days ago
# 3    jl_8e7a2074815a0521  permanent  data+scientist    2 days ago
# 4    jl_a48d2101a8c79123  permanent  data+scientist    8 days ago
# 5    jl_2ef1238fcfa3f7ef  permanent  data+scientist   14 days ago
# 6    jl_1c2067a43b42f93c  permanent  data+scientist    2 days ago
# 7    jl_6ef0e4669d224598  permanent  data+scientist    3 days ago
# 8    jl_4eb6eb7f377b9215  permanent  data+scientist  30+ days ago
# 9    jl_d69e84de1f1c38fc  permanent  data+scientist  30+ days ago
# 10   jl_f4b4fb6f85f5c519  permanent  data+scientist    8 days ago
# 11   jl_1e7d752f9231c7f9  permanent  data+scientist     1 day ago
# 12   jl_6aef216dbb75776d  permanent  data+scientist   16 days ago
# 13   jl_6912f8d657169a34  permanent  data+scientist  30+ days ago
# 14   jl_29d52f6b044e5bf9  permanent  data+scientist   25 days ago
# 15   jl_c8be98b859aaed20  permanent  data+scientist    6 days ago
# 16   jl_b694f4948b41a528  permanent  data+scientist    6 days ago
# 17   jl_1c337ac04e47d601  permanent  data+scientist     1 day ago
# 18   jl_a31294ccedf055c5  permanent  data+scientist   17 days ago
# 19   jl_7a5db9110ac22d0d  permanent  data+scientist    3 days ago
# 20   jl_377077675a7a517d  permanent  data+scientist   20 days ago
# 21   jl_024fc44d326557b3  permanent  data+scientist    5 days ago
# 22   jl_b5e23e2dc95774e9  permanent  data+scientist  30+ days ago
# 23   jl_c2311a9dc4f70eea  permanent  data+scientist    3 days ago
# 24   jl_cb55bff1bd0c73d5  permanent  data+scientist  22 hours ago
# 25   jl_a1298842fb6428e3  permanent  data+scientist  30+ days ago
# 26   jl_0fd84d77c4845eb4  permanent  data+scientist   27 days ago
# 27   jl_ddce70d6e7ba2b7c  permanent  data+scientist  23 hours ago
# 28   jl_a1cee8bad2e3528a  permanent  data+scientist   12 days ago
# 29   jl_e646ba9167b4c128  permanent  data+scientist   14 days ago
# ..                   ...        ...             ...           ...
# 914  jl_d0667423ec0f2a8d  permanent  data+scientist   23 days ago
# 915  jl_bbdc360aae9ef10b  permanent  data+scientist   14 days ago
# 916  jl_d1c76369b3c39423  permanent  data+scientist   13 days ago
# 917  jl_d73e9872d0a83cfe  permanent  data+scientist    3 days ago
# 918  jl_6208c05ffba2bbfb  permanent  data+scientist   20 days ago
# 919  jl_dbb886a212407b9b  permanent  data+scientist  30+ days ago
# 920  jl_d9e11a286c0bd0f8  permanent  data+scientist    9 days ago
# 921  jl_5c18559410a3588a  permanent  data+scientist    3 days ago
# 922  jl_925137fa02ca4428  permanent  data+scientist  30+ days ago
# 923  jl_ddb5bf0824275b69  permanent  data+scientist  30+ days ago
# 924  jl_90726cb9333f69c7  permanent  data+scientist  30+ days ago
# 925  jl_72c3539d35c954ed  permanent  data+scientist  30+ days ago
# 926  jl_33034e2e0c6d9e56  permanent  data+scientist  30+ days ago
# 927  jl_507b9bdbd0b732ce  permanent  data+scientist   23 days ago
# 928  jl_6f960756171c948d  permanent  data+scientist  30+ days ago
# 929  jl_6867261c3dd1acf0  permanent  data+scientist  30+ days ago
# 930  jl_4ee65ad33f4bc44c  permanent  data+scientist    2 days ago
# 931  jl_5df29c583944d45c  permanent  data+scientist  30+ days ago
# 932  jl_26c324ea4e4eff43  permanent  data+scientist    2 days ago
# 933  jl_ff9765b28a9b58fe  permanent  data+scientist    9 days ago
# 934  jl_e0ebb8f8566e2165  permanent  data+scientist  30+ days ago
# 935  jl_b6476f840d60301b  permanent  data+scientist   24 days ago
# 936  jl_e4b84149d76f1add  permanent  data+scientist    8 days ago
# 937  jl_b04b7f77d1ed71a5  permanent  data+scientist   10 days ago
# 938  jl_223d61d53612ebab  permanent  data+scientist   28 days ago
# 939  jl_79797981c430ece3  permanent  data+scientist   13 days ago
# 940  jl_c1ac90084c72a45e  permanent  data+scientist   24 days ago
# 941  jl_7bda5cb2a1637b27  permanent  data+scientist  30+ days ago
# 942  jl_e8ace30d24971614  permanent  data+scientist  30+ days ago
# 948  jl_c94f9b606be1c7e0  permanent  data+scientist   29 days ago
#
#                                              job_title  \
# 0                                       Data Scientist
# 1                              Graduate Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                Senior Data Scientist
# 5                                       Data Scientist
# 6                                       Data Scientist
# 7                                       Data Scientist
# 8                                 Data Scientist (AVP)
# 9                                       Data Scientist
# 10                               CMA951 Data Scientist
# 11                                Data Scientist - CRM
# 12                              Data Scientist Analyst
# 13                                      Data Scientist
# 14                                      Data Scientist
# 15                                      Data Scientist
# 16         Data Scientist Lead UK – Financial Services
# 17                                      Data Scientist
# 18                                      Data Scientist
# 19   Graduate Demand Forecasting & Usage Manager / ...
# 20                                      Data Scientist
# 21                                      Data Scientist
# 22                                      Data Scientist
# 23   Demand Forecasting & Usage Manager / Data Scie...
# 24                                 Scientist - Hinkley
# 25                               Senior Data Scientist
# 26                            Analyst / Data Scientist
# 27                               Junior Data Scientist
# 28                               Senior Data Scientist
# 29                             Merchant Data Scientist
# ..                                                 ...
# 914                           Analyst / Senior Analyst
# 915                                      Test Engineer
# 916  Principle Software Engineer – London – up to £...
# 917                                       AWS Engineer
# 918                                 Software Developer
# 919                      Back-End Developer AI Startup
# 920                                    Software Tester
# 921  Quantitative Risk Analyst – Credit Derivatives...
# 922                                Technical Team Lead
# 923  Software Engineer; C++, AI, Machine Learning, ...
# 924                                Front End Developer
# 925           Clinical Psychologist/ Neuropsychologist
# 926                         Quantitative Analyst (PHD)
# 927                             Senior Insight Analyst
# 928                      Director, Clinical Biomarkers
# 929  Algorithm, Physics, Modelling, Maths, C++, Sco...
# 930  Python Developer | NLP | Machine Learning | Ca...
# 931  R&D Software Engineer; Algorithms, DSP, C++, O...
# 932        Pre-Sales Engineer – Manufacturing Software
# 933                                  Marketing Manager
# 934      Software Developer in Test – Data Engineering
# 935             Software Development Manager - FinTech
# 936                  Senior Economist/Analyst - London
# 937                                Marketing Executive
# 938                          QC Manager - Microbiology
# 939  Information Scientist - Digital Content Delive...
# 940    Senior Optimisation Analyst (Insight) - Web/App
# 941                Digital Electronics Design Engineer
# 942                  DevOps Engineer - Linux/UNIX, AWS
# 948                           Head of Machine Learning
#
#                                        company                      salary  \
# 0                                     Barclays                         NaN
# 1                                      N Brown              £25,000 a year
# 2               Office for National Statistics              £35,200 a year
# 3                    Innovative Technology Ltd                         NaN
# 4               Office for National Statistics              £47,400 a year
# 5                     Ambassador Theatre Group    £45,000 - £55,000 a year
# 6                                     Inmarsat                         NaN
# 7                         Asset Resourcing Ltd    £60,000 - £80,000 a year
# 8                                     Barclays                         NaN
# 9                                 Saint-Gobain                         NaN
# 10             Competition & Markets Authority    £50,688 - £58,844 a year
# 11                                 Shop Direct                         NaN
# 12                 Lockheed Martin Corporation                         NaN
# 13                          Royal London Group                         NaN
# 14                                     SoulTek              £80,000 a year
# 15                    Wallgreen Boots Alliance                         NaN
# 16                                   Capgemini                         NaN
# 17            Durlston Partners London Limited    £50,000 - £70,000 a year
# 18                                      AFerry    £30,000 - £40,000 a year
# 19                       RAC Motoring Services                         NaN
# 20   Defence Science and Technology Laboratory    £25,000 - £36,000 a year
# 21                                       ADLIB                         NaN
# 22                           A.S. Watson Group                         NaN
# 23                       RAC Motoring Services                         NaN
# 24               Wessex Water Services Limited                         NaN
# 25                                    Barclays                         NaN
# 26                                Zipcar, Inc.                         NaN
# 27                                     Harnham    £30,000 - £35,000 a year
# 28       Office of Gas and Electricity Markets              £41,200 a year
# 29                                        Visa                         NaN
# ..                                         ...                         ...
# 914                         Ginger Recruitment    £26,000 - £32,000 a year
# 915              Manufacturing Recruitment Ltd                         NaN
# 916                        ReThink Recruitment    £75,000 - £78,000 a year
# 917                              Searchability                         NaN
# 918                                      ADLIB                         NaN
# 919                 Richard Wheeler Associates    £50,000 - £75,000 a year
# 920                                Spectrum IT              £45,000 a year
# 921                         Kite Human Capital  £100,000 - £120,000 a year
# 922                             Hydrogen Group                         NaN
# 923                                       re&m    £30,000 - £50,000 a year
# 924                 Richard Wheeler Associates    £50,000 - £75,000 a year
# 925                                   Fieldbay    £31,696 - £41,787 a year
# 926                           Octavius Finance                         NaN
# 927                           InterQuest Group              £40,000 a year
# 928                               Autolus Ltd.                         NaN
# 929                                       re&m    £30,000 - £40,000 a year
# 930                 Opus Recruitment Solutions    £35,000 - £50,000 a year
# 931                                       re&m    £30,000 - £50,000 a year
# 932                                    Senseye    £35,000 - £60,000 a year
# 933                          Inspiring Interns              £20,000 a year
# 934                             Hydrogen Group                         NaN
# 935                                   realTime    £50,000 - £60,000 a year
# 936                       Additional Resources    £50,000 - £57,000 a year
# 937                          Inspiring Interns              £22,000 a year
# 938                GXP Recruitment Specialists                         NaN
# 939                       Additional Resources              £30,000 a year
# 940                           InterQuest Group              £50,000 a year
# 941                                       re&m                         NaN
# 942                 Richard Wheeler Associates    £50,000 - £75,000 a year
# 948                        ReThink Recruitment   £70,000 - £100,000 a year
#
#                   location   no_of_review  \
# 0                  Glasgow  4,332 reviews
# 1           Manchester M60            NaN
# 2             Newport NP10     43 reviews
# 3                   Oldham     11 reviews
# 4             Newport NP10     43 reviews
# 5                   London     20 reviews
# 6                   London     32 reviews
# 7                    Leeds            NaN
# 8              Northampton  4,332 reviews
# 9            West Midlands  2,262 reviews
# 10             London WC1B      3 reviews
# 11               Liverpool    225 reviews
# 12              Gloucester  6,417 reviews
# 13               Edinburgh     36 reviews
# 14                 Glasgow            NaN
# 15              Nottingham            NaN
# 16                  London  6,077 reviews
# 17                  London            NaN
# 18                Abingdon            NaN
# 19                 Walsall    109 reviews
# 20           Salisbury SP4     17 reviews
# 21                Nuneaton            NaN
# 22                  London     41 reviews
# 23                 Walsall    109 reviews
# 24          United Kingdom      8 reviews
# 25                  London  4,332 reviews
# 26          Bracknell RG12            NaN
# 27                    Kent      6 reviews
# 28                  London            NaN
# 29                  London    657 reviews
# ..                     ...            ...
# 914             Manchester            NaN
# 915            West Sussex            NaN
# 916                 London     10 reviews
# 917             Manchester      5 reviews
# 918                 Exeter            NaN
# 919            London EC1Y            NaN
# 920                Fareham            NaN
# 921                 London            NaN
# 922                Glasgow      6 reviews
# 923          Home Counties            NaN
# 924            London EC1Y            NaN
# 925                Swansea            NaN
# 926                 London            NaN
# 927              Southgate      2 reviews
# 928             London W12            NaN
# 929               Scotland            NaN
# 930              Cambridge            NaN
# 931             South East            NaN
# 932            Southampton            NaN
# 933                 London      4 reviews
# 934             Nottingham      6 reviews
# 935                Belfast            NaN
# 936         Greater London            NaN
# 937           South London      4 reviews
# 938             Motherwell            NaN
# 939        Gloucestershire            NaN
# 940  London Bridge Station      2 reviews
# 941          West Midlands            NaN
# 942                 London            NaN
# 948                 London     10 reviews
#
#                                            job_summary
# 0    Data Scientist - 90210626. Job Title – Data Sc...
# 1    What a Data Scientist will be responsible for:...
# 2    We are recruiting a Data Scientist to fill a v...
# 3    Are you an experienced Data Scientist, who’s l...
# 4    As a Senior Data Scientist within the Data Sci...
# 5    The Data Scientist is a key role within the au...
# 6    Our work analyses the masses of data gathered ...
# 7    Data Science Consultant:. Work in collaboratio...
# 8    Data Scientist (AVP). Data Scientist (AVP) - 9...
# 9    In this exciting Data Scientist role you will ...
# 10   As a Data Scientist in the DaTA unit, you be a...
# 11   Our data scientists sit closely with our softw...
# 12   Experience of designing efficient algorithms f...
# 13   Nurture a more data driven approach to decisio...
# 14   We are seeking an experienced Data Scientist w...
# 15   Experienced in data science techniques (e.g. S...
# 16   The Data Scientist & Analytics Lead will under...
# 17   Clean data and build data pipelines using big-...
# 18   We are looking for an aspiring data scientist ...
# 19   Data skills with knowledge of relational datab...
# 20    Working with large data sets;  Large data s...
# 21   Reporting into an extremely talented Head of D...
# 22   Are you passionate about bringing data to life...
# 23   Proven experience working as a data scientist ...
# 24   This will include leading on, monitoring and a...
# 25   Senior Data Scientist. Senior Data Scientist -...
# 26   As the Analyst / Data Scientist, you will help...
# 27   JUNIOR DATA SCIENTIST. The data science team t...
# 28   Advanced data analysis, synthesis and data mo...
# 29   Merchant Data Scientist - London. Excellent un...
# ..                                                 ...
# 914  You are also giving your consent to your perso...
# 915  Working closely with R&D and scientists to tes...
# 916  Working closely with engineers, business partn...
# 917  You will work closely with the Data Scientists...
# 918  Co-operating with members of the team consisti...
# 919  Working with databases and relational data mod...
# 920  Manage own workload of jobs as tasked by the D...
# 921  Quantitative Risk Analyst – Credit Derivatives...
# 922  This is a brilliant opportunity to lead a team...
# 923  Software Engineers (C++)/ Problem solvers with...
# 924  The Front end Developer will join an experienc...
# 925  Maintain electronic data systems for monitorin...
# 926  Analytical and data driven thinker. You will b...
# 927  If you are looking for a role where you can de...
# 928  Mentor, guide and develop the clinical biomark...
# 929  Activities will include working with cross fun...
# 930  Data Mining experience. Knowledge of Object Or...
# 931  R&D (C++) Position for a scientist or software...
# 932  Familiarity with basic data analysis and data ...
# 933  Data analysis of website and social media anal...
# 934  Background of working with data scientists/arc...
# 935  The ideal person for this role will possess a ...
# 936  We endeavour to process your personal data in ...
# 937  Prepare and oversee delivery of data briefs, i...
# 938  Root cause analysis, trending and data analysi...
# 939  Information Scientist - Digital Content Delive...
# 940  This is a newly created role that forms part o...
# 941  Work closely with application, software engine...
# 942  The DevOps Engineer will join an experienced a...
# 948  Awareness of infrastructure issues, potential ...
#
# [944 rows x 10 columns]

# %%
generate_search_df('data analyst','permanent')
# Out:
# Searching for  data analyst and types
# Under  data analyst search for  permanent  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# Accessing page  31
#
# Accessing page  32
#
# Accessing page  33
#
# Accessing page  34
#
# Accessing page  35
#
# Accessing page  36
#
# Accessing page  37
#
# Accessing page  38
#
# Accessing page  39
#
# Accessing page  40
#
# Accessing page  41
#
# Accessing page  42
#
# Accessing page  43
#
# Accessing page  44
#
# Accessing page  45
#
# Accessing page  46
#
# Accessing page  47
#
# Accessing page  48
#
# Accessing page  49
#
# Accessing page  50
#
# Accessing page  51
#
# Accessing page  52
#
# Accessing page  53
#
# Accessing page  54
#
# Accessing page  55
#
# Accessing page  56
#
# Accessing page  57
#
# Accessing page  58
#
# Accessing page  59
#
# Accessing page  60
#
# Accessing page  61
#
# Accessing page  62
#
# Accessing page  63
#
# Accessing page  64
#
# Accessing page  65
#
# Accessing page  66
#
# Accessing page  67
#
# Accessing page  68
#
# Accessing page  69
#
# Accessing page  70
#
# Accessing page  71
#
# Accessing page  72
#
# Accessing page  73
#
# Accessing page  74
#
# Accessing page  75
#
# Accessing page  76
#
# Accessing page  77
#
# Accessing page  78
#
# Accessing page  79
#
# Accessing page  80
#
# Accessing page  81
#
# Accessing page  82
#
# Accessing page  83
#
# Accessing page  84
#
# Accessing page  85
#
# Accessing page  86
#
# Accessing page  87
#
# Accessing page  88
#
# Accessing page  89
#
# Accessing page  90
#
# Accessing page  91
#
# Accessing page  92
#
# Accessing page  93
#
# Accessing page  94
#
# Accessing page  95
#
# Accessing page  96
#
# Accessing page  97
#
# Accessing page  98
#
# Accessing page  99
#
# Accessing page  100
#
# Accessing page  101
#
# Accessing page  102
#
# Accessing page  103
#
# Accessing page  104
#
# It's done now! You can look at the output csv file.
# There are  1028 jobs successfully extracted.
#                    job_id  job_types       job_tag     post_time  \
# 0     jl_d8844c8a0c78b2ef  permanent  data+analyst   2 hours ago
# 1     jl_5c9490b54fdb4072  permanent  data+analyst   3 hours ago
# 2     jl_650cff5dfb789610  permanent  data+analyst   9 hours ago
# 3     jl_02c8bfacb7b2d1cb  permanent  data+analyst    2 days ago
# 4     jl_6b8942012bd01c63  permanent  data+analyst    2 days ago
# 5     jl_c2f2e1627367aad3  permanent  data+analyst  30+ days ago
# 6     jl_8639d5233cedec6a  permanent  data+analyst     1 day ago
# 7     jl_0c018b18cc1f4426  permanent  data+analyst     1 day ago
# 8     jl_2a2d280e3bb6893e  permanent  data+analyst    8 days ago
# 9     jl_95469b8d44cf0d18  permanent  data+analyst    2 days ago
# 10    jl_4022dd18dae161b7  permanent  data+analyst   20 days ago
# 11    jl_fd341e5d13b24a0e  permanent  data+analyst     1 day ago
# 12    jl_0f04a6633858db05  permanent  data+analyst    7 days ago
# 13    jl_1dd9d5871fee5770  permanent  data+analyst   3 hours ago
# 14    jl_708f838c76153238  permanent  data+analyst    6 days ago
# 15    jl_109395a747101130  permanent  data+analyst   13 days ago
# 16    jl_d0ca41023a81d735  permanent  data+analyst   14 days ago
# 17    jl_f8cd9f9111f3fe01  permanent  data+analyst    9 days ago
# 18    jl_fee61f5e016415e9  permanent  data+analyst   20 days ago
# 19    jl_fbc9c6385234ae43  permanent  data+analyst    9 days ago
# 20    jl_c690886c9a7af780  permanent  data+analyst  30+ days ago
# 21    jl_8e6b1b7a40b041d0  permanent  data+analyst  11 hours ago
# 22    jl_54232a4a90cea297  permanent  data+analyst  30+ days ago
# 23    jl_f0b045e86454ffa1  permanent  data+analyst     1 day ago
# 24    jl_c0de6f80a8505f8b  permanent  data+analyst  22 hours ago
# 25    jl_6aef216dbb75776d  permanent  data+analyst   16 days ago
# 26    jl_634716bfb9701d17  permanent  data+analyst    6 days ago
# 27    jl_a4db1c2c23a2068e  permanent  data+analyst    2 days ago
# 28    jl_f5aad32ac1a1a67e  permanent  data+analyst  30+ days ago
# 29    jl_0b7f1bfaafc567af  permanent  data+analyst    9 days ago
# ...                   ...        ...           ...           ...
# 998   jl_1b45cbb88917108d  permanent  data+analyst   19 days ago
# 999   jl_8db713575787e7a8  permanent  data+analyst  30+ days ago
# 3300  jl_eb2e248367fd0fef  permanent  data+analyst   14 days ago
# 3302  jl_a83b9f2dd69d4d01  permanent  data+analyst    6 days ago
# 3303  jl_227a8ac6c91f758c  permanent  data+analyst   26 days ago
# 3304  jl_bddfdccc82dc2381  permanent  data+analyst    6 days ago
# 3307  jl_c70042079d6b28da  permanent  data+analyst    7 days ago
# 3311  jl_50386c32b1e06847  permanent  data+analyst   9 hours ago
# 3312  jl_6ecb87a7c21bbebe  permanent  data+analyst  30+ days ago
# 3313  jl_9577f0dccc6a40cb  permanent  data+analyst  30+ days ago
# 3314  jl_a8bb0694f4a3c165  permanent  data+analyst  30+ days ago
# 3316  jl_d493a148f820c722  permanent  data+analyst  30+ days ago
# 3317  jl_2a096e76fdeca014  permanent  data+analyst   14 days ago
# 3318  jl_b74c311c3d64741d  permanent  data+analyst  30+ days ago
# 3319  jl_d0474ac52d32e62f  permanent  data+analyst   10 days ago
# 3320  jl_8c4cfd0c3154b9eb  permanent  data+analyst   23 days ago
# 3323  jl_557b617042824aa7  permanent  data+analyst  30+ days ago
# 3324  jl_1dc532198171d98f  permanent  data+analyst   19 days ago
# 3326  jl_4be10b062e2228b2  permanent  data+analyst    7 days ago
# 3330  jl_371dc2e042b1f410  permanent  data+analyst   7 hours ago
# 3331  jl_8fa1da0872665140  permanent  data+analyst    3 days ago
# 3333  jl_2dbf73d493630661  permanent  data+analyst  30+ days ago
# 3335  jl_62d13a7d744ed1e2  permanent  data+analyst   14 days ago
# 3337  jl_38fd94af2830acf5  permanent  data+analyst  30+ days ago
# 3338  jl_7ead85c614a6de4d  permanent  data+analyst  30+ days ago
# 3339  jl_23e5ecdcca5749c0  permanent  data+analyst  30+ days ago
# 3342  jl_117aa5ba60695276  permanent  data+analyst  30+ days ago
# 3348  jl_1b45cbb88917108d  permanent  data+analyst   19 days ago
# 3349  jl_8db713575787e7a8  permanent  data+analyst  30+ days ago
# 4249  jl_0900e04cd826b178  permanent  data+analyst  30+ days ago
#
#                                               job_title  \
# 0                                          Data Analyst
# 1                                          Data Analyst
# 2                            Data Visualisation Analyst
# 3                                   Retail Data Analyst
# 4                             Research and Data Analyst
# 5                              Data & Reporting Analyst
# 6                                          Data Analyst
# 7                                 Research Data Analyst
# 8                                  PowerBI Data Analyst
# 9                                Systems Analyst - Data
# 10                                 Trainee Data Analyst
# 11                    Band B2 - Data Analyst / Modeller
# 12                      Product Data Analyst Apprentice
# 13                                    Lead Data Analyst
# 14                                         Data Analyst
# 15                                         Data Analyst
# 16                                        Crime Analyst
# 17                                Customer Data Analyst
# 18                   Junior Overseas Operations Analyst
# 19                          HR Systems and Data Analyst
# 20                                     CRM DATA ANALYST
# 21                                  Junior Data Analyst
# 22                                         Data Analyst
# 23    G7 Data Science Analyst - Institute for Appren...
# 24                            Customer Research Analyst
# 25                               Data Scientist Analyst
# 26                                Graduate Data Analyst
# 27                               Data & Insight Analyst
# 28                                         Data Analyst
# 29                     EW Intelligence analyst - Oct 18
# ...                                                 ...
# 998                                             Analyst
# 999   Data Analyst- SQL- PowerBI- South London- GBP4...
# 3300                                         MI ANALYST
# 3302  Risk & Data Analyst - Financial Services - London
# 3303           Senior Data Analyst - Pharma, IQVIA, IMS
# 3304                            Finance Systems Analyst
# 3307                         Finance & Contract Analyst
# 3311                                   Business Analyst
# 3312                                        CRM Analyst
# 3313                               BI Developer/Analyst
# 3314                               BI Analyst Developer
# 3316                         ServiceNow Support Analyst
# 3317                              Group Finance Analyst
# 3318                        Logistics Packaging Analyst
# 3319                      Senior Data/Reporting Analyst
# 3320                                   Business Analyst
# 3323                            Senior Business Analyst
# 3324                Test Analyst *closing date extended
# 3326                                    Digital Analyst
# 3330                                    Finance Analyst
# 3331                  Head of Digital Delivery (London)
# 3333                       Regulatory Liquidity Analyst
# 3335                         Predictive Insight Analyst
# 3337                 Revenue Management Analyst - Italy
# 3338                 Revenue Management Analyst - Italy
# 3339                                 Customer Scientist
# 3342                          Digital Solutions Analyst
# 3348                                            Analyst
# 3349  Data Analyst- SQL- PowerBI- South London- GBP4...
# 4249                                       Head Analyst
#
#                                                 company  \
# 0                             Wilkinson Hardware Stores
# 1                                              Barclays
# 2                                              Barclays
# 3                             Jet2.com and Jet2holidays
# 4     Office of Qualifications and Examinations Regu...
# 5                                         Attwood Perks
# 6                            Legal & General Group Plc.
# 7                                                Which?
# 8                                            Rank Group
# 9                                          Costa Coffee
# 10                                         Hayley Group
# 11                                       Cabinet Office
# 12                                              N Brown
# 13                                             Barclays
# 14                                                ODEON
# 15                                     Jems Recruitment
# 16                                 Hertfordshire Police
# 17                                                  B&Q
# 18                            Jet2.com and Jet2holidays
# 19                                        Homes England
# 20                                           Kite Group
# 21                                       Global CTS Ltd
# 22                                          Avios Group
# 23                        Institute for Apprenticeships
# 24                               Leeds Building Society
# 25                          Lockheed Martin Corporation
# 26                        Tata Consultancy Services Ltd
# 27                                            Ascential
# 28                                The National Archives
# 29                                  Ministry of Defence
# ...                                                 ...
# 998                                       Office Angels
# 999                   Nigel Frank International Limited
# 3300                                             Spring
# 3302                           Twenty Recruitment Group
# 3303                                    Michael Page UK
# 3304                                         Hiscox Ltd
# 3307                                        Canada Life
# 3311                            Interaction Recruitment
# 3312                                            Harnham
# 3313                       DAS Legal Expenses Insurance
# 3314                                         Missguided
# 3316                                                SCC
# 3317                                            News UK
# 3318                                    Michael Page UK
# 3319                               Capita IT Resourcing
# 3320                                      Whitbread Plc
# 3323                                       Costa Coffee
# 3324                                   HM Land Registry
# 3326                                            Harnham
# 3330                                    Michael Page UK
# 3331                         Legal & General Group Plc.
# 3333                                    Michael Page UK
# 3335                                            Harnham
# 3337                                  Avis Budget Group
# 3338           Bracknell - Fixed Term & Permanent Hires
# 3339                                            Harnham
# 3342              Legal & General Investment Management
# 3348                                      Office Angels
# 3349                  Nigel Frank International Limited
# 4249                                            Harnham
#
#                         salary            location    no_of_review  \
# 0                          NaN             Worksop   1,246 reviews
# 1                          NaN             Glasgow   4,332 reviews
# 2                          NaN             Glasgow   4,332 reviews
# 3                          NaN               Leeds     135 reviews
# 4     £31,000 - £36,540 a year        Coventry CV1             NaN
# 5     £22,000 - £24,000 a year          Chelmsford             NaN
# 6     £35,000 - £40,000 a year                Hove      10 reviews
# 7                          NaN              London       9 reviews
# 8                          NaN          Maidenhead      18 reviews
# 9                          NaN           Dunstable   1,684 reviews
# 10                         NaN           Halesowen       3 reviews
# 11    £31,339 - £38,580 a year              London      27 reviews
# 12              £20,000 a year      Manchester M60             NaN
# 13                         NaN             Glasgow   4,332 reviews
# 14                         NaN       Manchester M1     108 reviews
# 15    £27,000 - £30,000 a year  Welwyn Garden City             NaN
# 16    £24,273 - £29,601 a year            Hatfield       9 reviews
# 17    £19,000 - £22,000 a year      Eastleigh SO53   1,648 reviews
# 18                         NaN               Leeds     135 reviews
# 19    £25,000 - £35,000 a year      Gateshead NE11       2 reviews
# 20    £30,000 - £35,000 a year              London             NaN
# 21              £24,000 a year              Oxford             NaN
# 22              £32,000 a year             Crawley      11 reviews
# 23              £48,493 a year            Coventry             NaN
# 24                         NaN               Leeds      39 reviews
# 25                         NaN          Gloucester   6,417 reviews
# 26              £27,000 a year             Warwick  14,022 reviews
# 27                         NaN              London       7 reviews
# 28    £32,175 - £38,000 a year        Richmond TW9       5 reviews
# 29              £25,383 a year         Lincoln LN5     405 reviews
# ...                        ...                 ...             ...
# 998             £25,000 a year             Ashford     148 reviews
# 999   £35,000 - £45,000 a year        South London      43 reviews
# 3300  £30,000 - £35,000 a year             Warwick             NaN
# 3302  £50,000 - £60,000 a year              London             NaN
# 3303  £50,000 - £65,000 a year          Maidenhead             NaN
# 3304                       NaN         London EC3A             NaN
# 3307                       NaN         Potters Bar             NaN
# 3311  £25,000 - £35,000 a year       Milton Keynes             NaN
# 3312  £27,000 - £37,500 a year              London             NaN
# 3313                       NaN             Bristol             NaN
# 3314                       NaN      Manchester M17             NaN
# 3316                       NaN          Birmingham             NaN
# 3317                       NaN              London             NaN
# 3318  £28,000 - £30,000 a year        Warwickshire             NaN
# 3319  £30,000 - £40,000 a year          Nottingham             NaN
# 3320                       NaN           Dunstable             NaN
# 3323                       NaN           Dunstable             NaN
# 3324            £4,609 a month            Plymouth             NaN
# 3326  £50,000 - £60,000 a year              London             NaN
# 3330  £50,000 - £55,000 a year              London             NaN
# 3331                       NaN              London             NaN
# 3333  £50,000 - £60,000 a year              London             NaN
# 3335  £35,000 - £70,000 a year              London             NaN
# 3337                       NaN      Bracknell RG12             NaN
# 3338                       NaN           Bracknell             NaN
# 3339  £30,000 - £40,000 a year              London             NaN
# 3342                       NaN              London             NaN
# 3348            £25,000 a year             Ashford             NaN
# 3349  £35,000 - £45,000 a year        South London             NaN
# 4249  £85,000 - £90,000 a year              London       6 reviews
#
#                                             job_summary
# 0     Provide / support the Data Governance team wit...
# 1     Data Analyst - 90210723. Job Title – Data Anal...
# 2     Data Visualisation Analyst. Data Visualisation...
# 3     Reporting to the Retail Revenue Manager, the R...
# 4      Working with others in the Data and Analytic...
# 5     Developing an understanding of data fields and...
# 6     Able to adapt to and work with change, in a fa...
# 7     We have an exciting opportunity for a Research...
# 8     Translates customer, transactional and behavio...
# 9     Previous experience of data mapping and data m...
# 10    Trainee Data Analyst. We have an exciting new ...
# 11    Sense-check data and weed out outliers or seek...
# 12    As our Product Data Analyst Apprentice you wil...
# 13    Lead Data Analyst - 90210694. Job Title – Lead...
# 14    Execute deep dives on data sets to understand ...
# 15    As a Data Analyst you will:. Are you an experi...
# 16    You will be working within a team of Crime Ana...
# 17    Customer Data Analyst. Knowledge of data manip...
# 18    In this fast paced and exciting role, you will...
# 19    Perform administrative functions including bus...
# 20    An understanding of data structure. Experience...
# 21    Data Analyst - grad opportunity, Wheatley, OX3...
# 22    Conduct data analysis - design and deliver the...
# 23     Data access - managing access to data source...
# 24    Highly numerate and data savvy. Leeds Building...
# 25    Experience of designing efficient algorithms f...
# 26    Data Analytics, Database background & Reportin...
# 27    We're looking for a Data & Insight Analyst to ...
# 28    Data Analyst (Catalogue and Taxonomy). Extensi...
# 29    As an Electronic Warfare (EW) Intelligence Ana...
# ...                                                 ...
# 998   Are you an experienced Analyst? Experience wor...
# 999   Data Analyst- SQL- PowerBI- South London- £43,...
# 3300  Demonstrable experience of working as an MI An...
# 3302  Twenty Financial Services are currently recrui...
# 3303  You will leverage IQVIA and various other data...
# 3304  Test changes to core data feeds to ensure data...
# 3307  Reconciling and reviewing data. IT Finance And...
# 3311  This position will utilise data warehouse tool...
# 3312  CRM Analyst - the Role. CRM Analyst - own a ca...
# 3313  As a BI Developer/ Analyst you will be:. Suppo...
# 3314  You will work directly for the Senior BI Data ...
# 3316  Overall Job Purpose( To perform 2nd / 3rd line...
# 3317  News UK acknowledges our responsibilities when...
# 3318  General administration, word processing, data ...
# 3319  These data sets will range from operational da...
# 3320  About the Business Analyst role:. Comprehensiv...
# 3323  Opportunity to be part of a thriving community...
# 3324   opening our data; We are now looking for Tes...
# 3326  8 year old agency with great reputation lookin...
# 3330  Comfortable with large amount of data and able...
# 3331  Very strong technical background either as a B...
# 3333  Good experience as a Financial Analyst or Repo...
# 3335  Predictive Insight Analyst. A well-known food ...
# 3337  Revenue Management Analyst - Italy. Our Revenu...
# 3338  Revenue Management Analyst - Italy. Our Revenu...
# 3339  This is an excellent role for an analyst to jo...
# 3342  Demonstrable analytical and data manipulation ...
# 3348  Are you an experienced Analyst? Experience wor...
# 3349  Data Analyst- SQL- PowerBI- South London- £43,...
# 4249  As Head Analyst you will primarily shape the p...
#
# [1028 rows x 10 columns]

# %%
generate_search_df('data engineer','permanent')
# Out:
# Searching for  data engineer and types
# Under  data engineer search for  permanent  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# Accessing page  31
#
# Accessing page  32
#
# Accessing page  33
#
# Accessing page  34
#
# Accessing page  35
#
# Accessing page  36
#
# Accessing page  37
#
# Accessing page  38
#
# Accessing page  39
#
# Accessing page  40
#
# Accessing page  41
#
# Accessing page  42
#
# Accessing page  43
#
# Accessing page  44
#
# Accessing page  45
#
# Accessing page  46
#
# Accessing page  47
#
# Accessing page  48
#
# Accessing page  49
#
# Accessing page  50
#
# Accessing page  51
#
# Accessing page  52
#
# Accessing page  53
#
# Accessing page  54
#
# Accessing page  55
#
# Accessing page  56
#
# Accessing page  57
#
# Accessing page  58
#
# Accessing page  59
#
# Accessing page  60
#
# Accessing page  61
#
# Accessing page  62
#
# Accessing page  63
#
# Accessing page  64
#
# Accessing page  65
#
# Accessing page  66
#
# Accessing page  67
#
# Accessing page  68
#
# Accessing page  69
#
# Accessing page  70
#
# Accessing page  71
#
# Accessing page  72
#
# Accessing page  73
#
# Accessing page  74
#
# Accessing page  75
#
# Accessing page  76
#
# Accessing page  77
#
# Accessing page  78
#
# Accessing page  79
#
# Accessing page  80
#
# Accessing page  81
#
# Accessing page  82
#
# Accessing page  83
#
# Accessing page  84
#
# Accessing page  85
#
# Accessing page  86
#
# Accessing page  87
#
# Accessing page  88
#
# Accessing page  89
#
# Accessing page  90
#
# Accessing page  91
#
# Accessing page  92
#
# Accessing page  93
#
# Accessing page  94
#
# Accessing page  95
#
# Accessing page  96
#
# Accessing page  97
#
# Accessing page  98
#
# Accessing page  99
#
# Accessing page  100
#
# Accessing page  101
#
# Accessing page  102
#
# Accessing page  103
#
# Accessing page  104
#
# Accessing page  105
#
# Accessing page  106
#
# Accessing page  107
#
# It's done now! You can look at the output csv file.
# There are  1048 jobs successfully extracted.
#                    job_id  job_types        job_tag     post_time  \
# 0     jl_0c101a183a2bb72e  permanent  data+engineer    8 days ago
# 1     jl_1b6051b03b8d9c83  permanent  data+engineer   23 days ago
# 2     jl_55fc29e7d7c20bac  permanent  data+engineer  22 hours ago
# 3     jl_5687f2b75f153096  permanent  data+engineer    2 days ago
# 4     jl_294d237b64fe6c8a  permanent  data+engineer    2 days ago
# 5     jl_24eef8c5def82a90  permanent  data+engineer  30+ days ago
# 6     jl_4e21ef92dcd89d02  permanent  data+engineer  30+ days ago
# 7     jl_740e28bccb2d441d  permanent  data+engineer    2 days ago
# 8     jl_3c3d8949a3f66650  permanent  data+engineer    2 days ago
# 9     jl_7bf59c332838f0b9  permanent  data+engineer    6 days ago
# 10    jl_662365212ba71b70  permanent  data+engineer  30+ days ago
# 11    jl_d4dd4d577cae1d69  permanent  data+engineer  30+ days ago
# 12    jl_c1845e2eecc71cbb  permanent  data+engineer     1 day ago
# 13    jl_3eb3fe3e4ec7eddd  permanent  data+engineer  30+ days ago
# 14    jl_d1c15041d36c0dd4  permanent  data+engineer   23 days ago
# 15    jl_23e7dee0c8775adb  permanent  data+engineer  30+ days ago
# 16    jl_8b4f8ce71460352b  permanent  data+engineer  30+ days ago
# 17    jl_1503b847031e6805  permanent  data+engineer    2 days ago
# 18    jl_adb88a90eaafc8b2  permanent  data+engineer    6 days ago
# 19    jl_27c147c6e5ec9799  permanent  data+engineer     1 day ago
# 20    jl_2ed8638ae8f5b1be  permanent  data+engineer     1 day ago
# 21    jl_1aba5c97bd13e96a  permanent  data+engineer  30+ days ago
# 22    jl_42b859a55baea2c6  permanent  data+engineer    4 days ago
# 23    jl_38c764822260cf38  permanent  data+engineer   30 days ago
# 24    jl_e10ddfb2454f1215  permanent  data+engineer  30+ days ago
# 25    jl_062ee504f1697a46  permanent  data+engineer  11 hours ago
# 26    jl_337c16a3eda935bd  permanent  data+engineer     1 day ago
# 27    jl_8ad86548c609c35f  permanent  data+engineer    7 days ago
# 28    jl_95f1254e57c321a8  permanent  data+engineer    9 days ago
# 29    jl_e068d67c77dc4aa7  permanent  data+engineer  30+ days ago
# ...                   ...        ...            ...           ...
# 1142  jl_94583ecf8cdf8766  permanent  data+engineer   12 days ago
# 1143  jl_2e235e2444f1b0ed  permanent  data+engineer    2 days ago
# 1144  jl_0084dceab1e8448d  permanent  data+engineer   10 days ago
# 1146  jl_14b71e5fd6327519  permanent  data+engineer   14 days ago
# 1147  jl_2e6daa8915ae9883  permanent  data+engineer   10 days ago
# 1148  jl_67a0de1905ef29a4  permanent  data+engineer   13 days ago
# 1901  jl_07e65eed1d45ca0e  permanent  data+engineer    6 days ago
# 1906  jl_d789fec83907eb7a  permanent  data+engineer    6 days ago
# 1909  jl_df96a50a7d79545a  permanent  data+engineer   19 days ago
# 1910  jl_198373b957a5626a  permanent  data+engineer     1 day ago
# 1913  jl_bfeac71a7abddfe9  permanent  data+engineer   26 days ago
# 1919  jl_fb4dccf104d1e15d  permanent  data+engineer   16 days ago
# 1922  jl_8664d342716d951e  permanent  data+engineer   13 days ago
# 1925  jl_48b3ad5b192b1174  permanent  data+engineer   20 days ago
# 1933  jl_4e365f854316a224  permanent  data+engineer   21 days ago
# 1936  jl_d112b583c8fbac0e  permanent  data+engineer   20 days ago
# 1938  jl_e9d070f6b8e33566  permanent  data+engineer   27 days ago
# 1941  jl_a387c040cd45688c  permanent  data+engineer   27 days ago
# 1945  jl_46a0252f141acc3f  permanent  data+engineer  30+ days ago
# 1946  jl_04cd1fd680b60317  permanent  data+engineer    7 days ago
# 1947  jl_907c4c17f3b71387  permanent  data+engineer   29 days ago
# 3306  jl_d789fec83907eb7a  permanent  data+engineer    6 days ago
# 3309  jl_df96a50a7d79545a  permanent  data+engineer   19 days ago
# 3312  jl_c06ac1065d76211a  permanent  data+engineer   22 days ago
# 3314  jl_adb67c96d6596a8c  permanent  data+engineer    2 days ago
# 3319  jl_fb4dccf104d1e15d  permanent  data+engineer   16 days ago
# 3333  jl_4e365f854316a224  permanent  data+engineer   21 days ago
# 3336  jl_d112b583c8fbac0e  permanent  data+engineer   20 days ago
# 3341  jl_a387c040cd45688c  permanent  data+engineer   27 days ago
# 3345  jl_46a0252f141acc3f  permanent  data+engineer  30+ days ago
#
#                                               job_title  \
# 0                                 Engineer (Data) - x 2
# 1                                         Data Engineer
# 2                                         Data Engineer
# 3                                         Data Engineer
# 4                                         Data Engineer
# 5                                      BI Data Engineer
# 6                                         Data Engineer
# 7                    Data Analyst & Simulation Engineer
# 8                    Data Analyst & Simulation Engineer
# 9                                         Data Engineer
# 10                                        Data Engineer
# 11       Data Engineer – Permanent – Leeds – up to £40K
# 12                                    Engineer Big Data
# 13                                        Data Engineer
# 14                             Kibana Big Data Engineer
# 15                                        Data Engineer
# 16    Data Engineer (ETL) – Permanent – Leeds – up t...
# 17                                     Project Engineer
# 18                                        Data Engineer
# 19                                        Data Engineer
# 20                                    Big Data Engineer
# 21                                        Data Engineer
# 22                                        Data Engineer
# 23                              Principle Data Engineer
# 24                                          Data Centre
# 25                                        Data Engineer
# 26                             Junior Big Data Engineer
# 27                Assistant Design Engineer (permanent)
# 28                                        Data Engineer
# 29                                   Lead Data Engineer
# ...                                                 ...
# 1142                               Head of Data Science
# 1143                                        AV Engineer
# 1144                           Infrastructure Architect
# 1146                         Refrigeration R&D Engineer
# 1147                             ADAS/CAV Test Engineer
# 1148                                Fuel Cycle Engineer
# 1901                                             Burner
# 1906                             Data Centre Supervisor
# 1909                       Application Support Engineer
# 1910                                  Software Engineer
# 1913                                       ICT Engineer
# 1919                            GLOBAL NETWORK ENGINEER
# 1922                            Bioinformatics Engineer
# 1925                                   Quality Engineer
# 1933                               Engine Test Engineer
# 1936                Senior Maintenance Systems Engineer
# 1938              Artificial Intelligence (AI) Engineer
# 1941                                  VPBX/SIP Engineer
# 1945                 Platform Services Network Engineer
# 1946                                IT Support Engineer
# 1947  Telecoms Exchange Maintenance Engineer - Yorks...
# 3306                             Data Centre Supervisor
# 3309                       Application Support Engineer
# 3312                      FCRM Technical Advisor - 9178
# 3314                         DevOps / Software Engineer
# 3319                            GLOBAL NETWORK ENGINEER
# 3333                               Engine Test Engineer
# 3336                Senior Maintenance Systems Engineer
# 3341                                  VPBX/SIP Engineer
# 3345                 Platform Services Network Engineer
#
#                                        company                    salary  \
# 0            University of the West of England  £29,515 - £33,199 a year
# 1                                  Shop Direct                       NaN
# 2                                     Barclays                       NaN
# 3                               Arnold Ash Ltd  £60,000 - £75,000 a year
# 4                 Brightred Resourcing Limited  £50,000 - £60,000 a year
# 5                               Babylon Health                       NaN
# 6                                        Argos                       NaN
# 7                                 Buro Happold                       NaN
# 8                      BuroHappold Engineering                       NaN
# 9                      Digitech Resourcing Ltd  £60,000 - £80,000 a year
# 10                               Kindred Group                       NaN
# 11                                  The Bridge            £40,000 a year
# 12                            Talent Point Ltd  £50,000 - £80,000 a year
# 13                             Hastings Direct                       NaN
# 14                                    Barclays                       NaN
# 15                                    WorldPay                       NaN
# 16                                  The Bridge            £40,000 a year
# 17                        William Grant & Sons                       NaN
# 18                    Es Field Delivery Uk Ltd            £24,000 a year
# 19              ArnoldRees Recruitment Limited  £22,000 - £25,000 a year
# 20                               Austin Fraser         £500 - £501 a day
# 21                                        BJSS                       NaN
# 22                            InterQuest Group                       NaN
# 23                      UK Hydrographic Office  £50,041 - £56,363 a year
# 24           Skyline Engineering Solutions LTD                       NaN
# 25                            Gibbs Hybrid Ltd  £50,000 - £60,000 a year
# 26                               GL Global Ltd  £50,000 - £60,000 a year
# 27       Merthyr Tydfil County Borough Council                       NaN
# 28           Michael Weaver Associates Limited  £30,000 - £33,500 a year
# 29                                     SoulTek            £90,000 a year
# ...                                        ...                       ...
# 1142                               Cogs Agency           £100,000 a year
# 1143                         Apple Recruitment                       NaN
# 1144                                       BPP  £60,000 - £65,000 a year
# 1146                            E3 Recruitment  £28,000 - £32,000 a year
# 1147              Jonathan Lee Recruitment Ltd                       NaN
# 1148                                  Fircroft                       NaN
# 1901                         JS Recruitment UK  £30,000 - £40,000 a year
# 1906                          Resourcing Group  £43,000 - £46,000 a year
# 1909                                Gold Group  £30,000 - £35,000 a year
# 1910  Software Personnel International Limited  £45,000 - £50,000 a year
# 1913                           Identifi Global                       NaN
# 1919                                    Spring            £60,000 a year
# 1922                                  Haybrook  £50,000 - £65,000 a year
# 1925                            CG Consultants                       NaN
# 1933              Jonathan Lee Recruitment Ltd                       NaN
# 1936                                      Wood                       NaN
# 1938                    Bluestream Recruitment                       NaN
# 1941                                   Experis                       NaN
# 1945                                  Claranet                       NaN
# 1946                Syntax Consultancy Limited  £21,000 - £24,000 a year
# 1947                        Integra People Ltd  £25,000 - £33,000 a year
# 3306                          Resourcing Group  £43,000 - £46,000 a year
# 3309                                Gold Group  £30,000 - £35,000 a year
# 3312                        Environment Agency  £30,001 - £40,000 a year
# 3314            Office for National Statistics            £35,200 a year
# 3319                                    Spring            £60,000 a year
# 3333              Jonathan Lee Recruitment Ltd                       NaN
# 3336                                      Wood                       NaN
# 3341                                   Experis                       NaN
# 3345                                  Claranet                       NaN
#
#               location   no_of_review  \
# 0              Bristol     40 reviews
# 1            Liverpool    225 reviews
# 2          Northampton  4,332 reviews
# 3               London            NaN
# 4               London            NaN
# 5               London            NaN
# 6        Milton Keynes  2,609 reviews
# 7               London      9 reviews
# 8               London     12 reviews
# 9               London            NaN
# 10              London      4 reviews
# 11               Leeds     14 reviews
# 12              London            NaN
# 13        Bexhill TN39    144 reviews
# 14         Northampton  4,332 reviews
# 15              London    192 reviews
# 16               Leeds     14 reviews
# 17            Dufftown     18 reviews
# 18           Cleveland            NaN
# 19           Edinburgh            NaN
# 20         Oxfordshire     15 reviews
# 21              London            NaN
# 22                York      2 reviews
# 23          South West      3 reviews
# 24      United Kingdom            NaN
# 25              London            NaN
# 26         East London            NaN
# 27      Merthyr Tydfil     11 reviews
# 28         Farnborough            NaN
# 29              London            NaN
# ...                ...            ...
# 1142            London            NaN
# 1143  Northern Ireland            NaN
# 1144       London EC2M            NaN
# 1146           Shipley            NaN
# 1147          Nuneaton            NaN
# 1148        Gloucester            NaN
# 1901         Guildford            NaN
# 1906       Farnborough     20 reviews
# 1909           Bromley      3 reviews
# 1910         Lingfield            NaN
# 1913           Bristol            NaN
# 1919          Coventry     32 reviews
# 1922       West London            NaN
# 1925         St Albans            NaN
# 1933           Royston      4 reviews
# 1936          Aberdeen    944 reviews
# 1938            Didcot            NaN
# 1941          Hatfield    569 reviews
# 1945       London WC1B      9 reviews
# 1946       East London            NaN
# 1947    West Yorkshire            NaN
# 3306       Farnborough            NaN
# 3309           Bromley            NaN
# 3312      Gainsborough            NaN
# 3314      Newport NP10            NaN
# 3319          Coventry            NaN
# 3333           Royston            NaN
# 3336          Aberdeen            NaN
# 3341          Hatfield            NaN
# 3345       London WC1B            NaN
#
#                                             job_summary
# 0     In this role you would be supporting the Princ...
# 1     We work cross-functionally to make our data co...
# 2     Data Engineer - 90208128. Conceptualize and qu...
# 3     Data Engineer - Data Science. Data Engineer - ...
# 4     Main Job duties and Responsibilities of Data E...
# 5     Bringing data from different data sources and ...
# 6     To help with this journey, we are looking for ...
# 7     With the role of Data Analyst & Simulation Eng...
# 8     With the role of Data Analyst & Simulation Eng...
# 9     Data Engineer benefits:. As the Data Engineer ...
# 10    5+ years of professional experience as a Data ...
# 11    Data Engineer – ETL. Previous experience as a ...
# 12    Data Engineer - Big Data. Superb new Data Engi...
# 13    Hastings Direct, Data Engineer. As a Data Engi...
# 14    Kibana Big Data Engineer - 90199839. Job Title...
# 15    We’re looking for a Data Engineer with softwar...
# 16    Data Engineer – ETL. Previous experience as a ...
# 17    Provide clear and concise technical project re...
# 18    However we can help the Data Centre Engineer a...
# 19    Due to expansion, they are looking to add two ...
# 20    Big Data Engineer, 6 Months, Oxfordshire, £500...
# 21    Are you a skilled data engineer who has helped...
# 22    Senior Data Engineer | New York.  Lead the de...
# 23    Principle Data Engineer. You will have a demon...
# 24    Mechanical and Electrical Engineer (Data Centr...
# 25    Data Engineer, London, Ecommerce, Power BI. My...
# 26    We have an exciting new position within a high...
# 27    This is an excellent opportunity for an Assist...
# 28    We are recruiting Data Centre Engineers with e...
# 29    SoulTek’s client a fast growing technology com...
# ...                                                 ...
# 1142  Cogs are currently working with a top London b...
# 1143  Audio Visual Engineer. This may require site s...
# 1144  Provide technical troubleshooting services for...
# 1146  Strong IT skills including MS Office, Data Log...
# 1147  Good data acquisition, data analysis and post ...
# 1148  Fircroft is registered as a Data Controller wi...
# 1901  If you are shortlisted, JS Recruitment UK Ltd ...
# 1906  Significant experience as a building service e...
# 1909  Application Support Engineer. Roles and Respon...
# 1910  Software Engineer - Computer Vision, C++, QT, ...
# 1913  Data Base (MS SQL, Oracle). ICT Engineer – Bir...
# 1919  Global Network Engineer. The Global Network En...
# 1922  Responsibilities of the Bioinformatics Enginee...
# 1925  Quality Engineer / QE. As the Quality Engineer...
# 1933  Engine Test Engineer. As an Engine Test Engine...
# 1936  Develop data definition guide as per Data Proj...
# 1938  As AI Engineer you will be required to:. To be...
# 1941  Experience in vitalised data centres. To maint...
# 1945  Troubleshoot affectively by defining problems,...
# 1946  Business Intelligence (BI) / Data Warehousing....
# 1947  Experience of working in BT Exchanges and Data...
# 3306  Significant experience as a building service e...
# 3309  Application Support Engineer. Roles and Respon...
# 3312  Our teams are a mix of civil engineers, data/i...
# 3314  The DevOps / Software engineer will work close...
# 3319  Global Network Engineer. The Global Network En...
# 3333  Engine Test Engineer. As an Engine Test Engine...
# 3336  Develop data definition guide as per Data Proj...
# 3341  Experience in vitalised data centres. To maint...
# 3345  Troubleshoot affectively by defining problems,...
#
# [1048 rows x 10 columns]

# %%
generate_search_df('research scientist','permanent')
# Out:
# Searching for  research scientist and types
# Under  research scientist search for  permanent  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# It's done now! You can look at the output csv file.
# There are  491 jobs successfully extracted.
#                 job_id  job_types             job_tag    post_time  \
# 0  jl_aa82ca0de298dbe6  permanent  research+scientist  22 days ago
# 1  jl_7c6c809b5e0f60d9  permanent  research+scientist   8 days ago
#
#                       job_title                                    company  \
# 0  Explosive Research Scientist  Defence Science and Technology Laboratory
# 1          Laboratory Scientist                              Anthony Nolan
#
#                      salary       location no_of_review  \
# 0  £31,500 - £35,500 a year  Salisbury SP4   17 reviews
# 1            £25,000 a year         London    5 reviews
#
#                                          job_summary
# 0   Delivering high quality research to meet oft...
# 1  We are looking for a Laboratory Scientist to j...

# %%
generate_search_df('business intelligence','permanent')
# Out:
# Searching for  business intelligence and types
# Under  business intelligence search for  permanent  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# Accessing page  31
#
# Accessing page  32
#
# Accessing page  33
#
# Accessing page  34
#
# Accessing page  35
#
# Accessing page  36
#
# Accessing page  37
#
# Accessing page  38
#
# Accessing page  39
#
# Accessing page  40
#
# Accessing page  41
#
# Accessing page  42
#
# Accessing page  43
#
# Accessing page  44
#
# Accessing page  45
#
# Accessing page  46
#
# Accessing page  47
#
# Accessing page  48
#
# Accessing page  49
#
# Accessing page  50
#
# Accessing page  51
#
# Accessing page  52
#
# Accessing page  53
#
# Accessing page  54
#
# Accessing page  55
#
# Accessing page  56
#
# Accessing page  57
#
# Accessing page  58
#
# Accessing page  59
#
# Accessing page  60
#
# It's done now! You can look at the output csv file.
# There are  1000 jobs successfully extracted.
#                 job_id  job_types                job_tag     post_time  \
# 0  jl_1c4bbb310c1865b4  permanent  business+intelligence  21 hours ago
# 1  jl_8561f1b6cd4a665e  permanent  business+intelligence    6 days ago
#
#                          job_title         company          salary   location  \
# 0  Business Intelligence Developer           Codex  £35,000 a year  Hampshire
# 1  Business Intelligence Developer  Joules Limited             NaN      Corby
#
#   no_of_review                                        job_summary
# 0   10 reviews  Business Intelligence Developer (Qlikview) - L...
# 1          NaN  Supporting the day to day running of Joules Bu...

# %%
generate_search_df('analytics','permanent')
# Out:
# Searching for  analytics and types
# Under  analytics search for  permanent  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# Accessing page  31
#
# Accessing page  32
#
# Accessing page  33
#
# Accessing page  34
#
# Accessing page  35
#
# Accessing page  36
#
# Accessing page  37
#
# Accessing page  38
#
# Accessing page  39
#
# Accessing page  40
#
# Accessing page  41
#
# Accessing page  42
#
# Accessing page  43
#
# Accessing page  44
#
# Accessing page  45
#
# Accessing page  46
#
# Accessing page  47
#
# Accessing page  48
#
# Accessing page  49
#
# Accessing page  50
#
# Accessing page  51
#
# Accessing page  52
#
# Accessing page  53
#
# Accessing page  54
#
# Accessing page  55
#
# Accessing page  56
#
# Accessing page  57
#
# Accessing page  58
#
# Accessing page  59
#
# Accessing page  60
#
# Accessing page  61
#
# Accessing page  62
#
# Accessing page  63
#
# Accessing page  64
#
# Accessing page  65
#
# Accessing page  66
#
# Accessing page  67
#
# Accessing page  68
#
# Accessing page  69
#
# Accessing page  70
#
# Accessing page  71
#
# Accessing page  72
#
# Accessing page  73
#
# Accessing page  74
#
# Accessing page  75
#
# Accessing page  76
#
# Accessing page  77
#
# Accessing page  78
#
# Accessing page  79
#
# Accessing page  80
#
# Accessing page  81
#
# Accessing page  82
#
# Accessing page  83
#
# Accessing page  84
#
# Accessing page  85
#
# Accessing page  86
#
# Accessing page  87
#
# Accessing page  88
#
# Accessing page  89
#
# Accessing page  90
#
# Accessing page  91
#
# Accessing page  92
#
# Accessing page  93
#
# Accessing page  94
#
# Accessing page  95
#
# Accessing page  96
#
# Accessing page  97
#
# Accessing page  98
#
# Accessing page  99
#
# Accessing page  100
#
# Accessing page  101
#
# Accessing page  102
#
# Accessing page  103
#
# Accessing page  104
#
# Accessing page  105
#
# Accessing page  106
#
# Accessing page  107
#
# Accessing page  108
#
# Accessing page  109
#
# Accessing page  110
#
# Accessing page  111
#
# Accessing page  112
#
# Accessing page  113
#
# Accessing page  114
#
# Accessing page  115
#
# Accessing page  116
#
# Accessing page  117
#
# Accessing page  118
#
# Accessing page  119
#
# Accessing page  120
#
# Accessing page  121
#
# Accessing page  122
#
# Accessing page  123
#
# Accessing page  124
#
# Accessing page  125
#
# Accessing page  126
#
# It's done now! You can look at the output csv file.
# There are  1050 jobs successfully extracted.
#                 job_id  job_types    job_tag   post_time  \
# 0  jl_aefa77662d5bfc1d  permanent  analytics  6 days ago
# 1  jl_b31a196a2fff5772  permanent  analytics   1 day ago
#
#                                            job_title     company salary  \
# 0               Head of Customer Insight & Analytics  Rank Group    NaN
# 1  Advanced Analytics Consultant (Predictive, AI,...  Capita Plc    NaN
#
#      location   no_of_review  \
# 0  Maidenhead     18 reviews
# 1   Edinburgh  2,017 reviews
#
#                                          job_summary
# 0  � Responsible for leading a team of Analysts a...
# 1  Become an Advanced Analytics Consultant with B...

# %%
generate_search_df('data scientist','fulltime')
# Out:
# Searching for  data scientist and types
# Under  data scientist search for  fulltime  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# It's done now! You can look at the output csv file.
# There are  1000 jobs successfully extracted.
#                 job_id job_types         job_tag    post_time  \
# 0  jl_6635075b094accda  fulltime  data+scientist    1 day ago
# 1  jl_950a6428afc8792c  fulltime  data+scientist  10 days ago
#
#                job_title                         company          salary  \
# 0  Data Scientist Intern                        Illumina             NaN
# 1         Data Scientist  Office for National Statistics  £35,200 a year
#
#        location no_of_review  \
# 0       England  144 reviews
# 1  Newport NP10   43 reviews
#
#                                          job_summary
# 0  Data Scientist Intern. Machine Learning on DNA...
# 1  We are recruiting a Data Scientist to fill a v...

# %%
generate_search_df('data analyst','fulltime')
# Out:
# Searching for  data analyst and types
# Under  data analyst search for  fulltime  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# Accessing page  31
#
# Accessing page  32
#
# Accessing page  33
#
# Accessing page  34
#
# Accessing page  35
#
# Accessing page  36
#
# Accessing page  37
#
# Accessing page  38
#
# Accessing page  39
#
# Accessing page  40
#
# Accessing page  41
#
# Accessing page  42
#
# Accessing page  43
#
# Accessing page  44
#
# Accessing page  45
#
# Accessing page  46
#
# Accessing page  47
#
# Accessing page  48
#
# Accessing page  49
#
# Accessing page  50
#
# Accessing page  51
#
# Accessing page  52
#
# Accessing page  53
#
# Accessing page  54
#
# Accessing page  55
#
# Accessing page  56
#
# Accessing page  57
#
# Accessing page  58
#
# Accessing page  59
#
# Accessing page  60
#
# Accessing page  61
#
# Accessing page  62
#
# Accessing page  63
#
# Accessing page  64
#
# Accessing page  65
#
# Accessing page  66
#
# Accessing page  67
#
# Accessing page  68
#
# Accessing page  69
#
# Accessing page  70
#
# Accessing page  71
#
# Accessing page  72
#
# Accessing page  73
#
# Accessing page  74
#
# Accessing page  75
#
# Accessing page  76
#
# Accessing page  77
#
# Accessing page  78
#
# Accessing page  79
#
# Accessing page  80
#
# Accessing page  81
#
# Accessing page  82
#
# It's done now! You can look at the output csv file.
# There are  1000 jobs successfully extracted.
#                 job_id job_types       job_tag    post_time  \
# 0  jl_3b7d740f0102253d  fulltime  data+analyst  22 days ago
# 1  jl_e35d91216e282815  fulltime  data+analyst   3 days ago
#
#                                   job_title  \
# 0  Trainee Quality Improvement Data Analyst
# 1                              Data Analyst
#
#                               company                    salary   location  \
# 0    East London NHS Foundation Trust  £27,628 - £35,530 a year  London E1
# 1  Royal Cornwall Hospitals NHS Trust  £28,050 - £36,644 a year  Truro TR1
#
#   no_of_review                                        job_summary
# 0   21 reviews  The Trainee Data Analyst will form part of the...
# 1    2 reviews  Someone who can link data together to present ...

# %%
generate_search_df('data engineer','fulltime')
# Out:
# Searching for  data engineer and types
# Under  data engineer search for  fulltime  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# Accessing page  31
#
# Accessing page  32
#
# Accessing page  33
#
# Accessing page  34
#
# Accessing page  35
#
# Accessing page  36
#
# Accessing page  37
#
# Accessing page  38
#
# Accessing page  39
#
# Accessing page  40
#
# Accessing page  41
#
# Accessing page  42
#
# Accessing page  43
#
# Accessing page  44
#
# Accessing page  45
#
# Accessing page  46
#
# Accessing page  47
#
# Accessing page  48
#
# Accessing page  49
#
# Accessing page  50
#
# Accessing page  51
#
# Accessing page  52
#
# Accessing page  53
#
# Accessing page  54
#
# Accessing page  55
#
# Accessing page  56
#
# Accessing page  57
#
# Accessing page  58
#
# Accessing page  59
#
# Accessing page  60
#
# Accessing page  61
#
# Accessing page  62
#
# Accessing page  63
#
# Accessing page  64
#
# Accessing page  65
#
# Accessing page  66
#
# Accessing page  67
#
# Accessing page  68
#
# Accessing page  69
#
# Accessing page  70
#
# Accessing page  71
#
# Accessing page  72
#
# Accessing page  73
#
# Accessing page  74
#
# Accessing page  75
#
# Accessing page  76
#
# Accessing page  77
#
# Accessing page  78
#
# Accessing page  79
#
# Accessing page  80
#
# Accessing page  81
#
# Accessing page  82
#
# Accessing page  83
#
# Accessing page  84
#
# Accessing page  85
#
# Accessing page  86
#
# Accessing page  87
#
# Accessing page  88
#
# Accessing page  89
#
# Accessing page  90
#
# Accessing page  91
#
# Accessing page  92
#
# Accessing page  93
#
# Accessing page  94
#
# Accessing page  95
#
# Accessing page  96
#
# Accessing page  97
#
# Accessing page  98
#
# Accessing page  99
#
# Accessing page  100
#
# Accessing page  101
#
# Accessing page  102
#
# Accessing page  103
#
# Accessing page  104
#
# Accessing page  105
#
# Accessing page  106
#
# It's done now! You can look at the output csv file.
# There are  1043 jobs successfully extracted.
#                 job_id job_types        job_tag    post_time  \
# 0  jl_64eaa46804364549  fulltime  data+engineer  11 days ago
# 1  jl_7c235a26d266283a  fulltime  data+engineer   2 days ago
#
#                     job_title company salary   location   no_of_review  \
# 0  Graduate Big Data Engineer   Jagex    NaN  Cambridge      4 reviews
# 1               Data Engineer     RBS    NaN  Edinburgh  2,920 reviews
#
#                                          job_summary
# 0  As Graduate Big Data Engineer, you will:. Jage...
# 1  As a data engineer, you'll be supporting data ...

# %%
generate_search_df('research scientist','fulltime')
# Out:
# Searching for  research scientist and types
# Under  research scientist search for  fulltime  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# It's done now! You can look at the output csv file.
# There are  1000 jobs successfully extracted.
#                 job_id job_types             job_tag   post_time  \
# 0  jl_a407a4dfaf332ef1  fulltime  research+scientist  5 days ago
# 1  jl_bd0cfe61a897cc7e  fulltime  research+scientist  9 days ago
#
#                      job_title  \
# 0       R&D Research Scientist
# 1  Research Vascular Scientist
#
#                                              company  \
# 0                                           ConvaTec
# 1  Chelsea and Westminster Hospital NHS Foundatio...
#
#                      salary       location no_of_review  \
# 0                       NaN        Deeside  136 reviews
# 1  £26,682 - £34,049 a year  Isleworth TW7   11 reviews
#
#                                          job_summary
# 0  Proven research & development laboratory testi...
# 1  Research Vascular Scientist, West Middlesex Lo...

# %%
generate_search_df('business intelligence','fulltime')
# Out:
# Searching for  business intelligence and types
# Under  business intelligence search for  fulltime  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# Accessing page  31
#
# Accessing page  32
#
# Accessing page  33
#
# Accessing page  34
#
# Accessing page  35
#
# Accessing page  36
#
# Accessing page  37
#
# Accessing page  38
#
# Accessing page  39
#
# Accessing page  40
#
# Accessing page  41
#
# Accessing page  42
#
# Accessing page  43
#
# Accessing page  44
#
# Accessing page  45
#
# Accessing page  46
#
# Accessing page  47
#
# Accessing page  48
#
# Accessing page  49
#
# Accessing page  50
#
# Accessing page  51
#
# Accessing page  52
#
# Accessing page  53
#
# Accessing page  54
#
# Accessing page  55
#
# Accessing page  56
#
# Accessing page  57
#
# Accessing page  58
#
# Accessing page  59
#
# Accessing page  60
#
# Accessing page  61
#
# Accessing page  62
#
# Accessing page  63
#
# Accessing page  64
#
# Accessing page  65
#
# Accessing page  66
#
# Accessing page  67
#
# Accessing page  68
#
# Accessing page  69
#
# Accessing page  70
#
# Accessing page  71
#
# Accessing page  72
#
# Accessing page  73
#
# Accessing page  74
#
# It's done now! You can look at the output csv file.
# There are  1036 jobs successfully extracted.
#                 job_id job_types                job_tag   post_time  \
# 0  jl_a6aac63c6c160a07  fulltime  business+intelligence  3 days ago
# 1  jl_5873a76350c2f1ef  fulltime  business+intelligence  7 days ago
#
#                           job_title  \
# 0  Business Intelligence Internship
# 1     Business Intelligence Officer
#
#                                              company  \
# 0                                    Kapeinternships
# 1  Central and North West London NHS Foundation T...
#
#                      salary    location no_of_review  \
# 0                       NaN      London          NaN
# 1  £26,565 - £42,046 a year  London NW1   16 reviews
#
#                                          job_summary
# 0  Distributing these templated Business Intellig...
# 1  An exciting opportunity has arisen for a Busin...

# %%
generate_search_df('analytics','fulltime')
# Out:
# Searching for  analytics and types
# Under  analytics search for  fulltime  job
# Accessing page  0
#
# Accessing page  1
#
# Accessing page  2
#
# Accessing page  3
#
# Accessing page  4
#
# Accessing page  5
#
# Accessing page  6
#
# Accessing page  7
#
# Accessing page  8
#
# Accessing page  9
#
# Accessing page  10
#
# Accessing page  11
#
# Accessing page  12
#
# Accessing page  13
#
# Accessing page  14
#
# Accessing page  15
#
# Accessing page  16
#
# Accessing page  17
#
# Accessing page  18
#
# Accessing page  19
#
# Accessing page  20
#
# Accessing page  21
#
# Accessing page  22
#
# Accessing page  23
#
# Accessing page  24
#
# Accessing page  25
#
# Accessing page  26
#
# Accessing page  27
#
# Accessing page  28
#
# Accessing page  29
#
# Accessing page  30
#
# Accessing page  31
#
# Accessing page  32
#
# Accessing page  33
#
# Accessing page  34
#
# Accessing page  35
#
# Accessing page  36
#
# Accessing page  37
#
# Accessing page  38
#
# Accessing page  39
#
# Accessing page  40
#
# Accessing page  41
#
# Accessing page  42
#
# Accessing page  43
#
# Accessing page  44
#
# Accessing page  45
#
# Accessing page  46
#
# Accessing page  47
#
# Accessing page  48
#
# Accessing page  49
#
# Accessing page  50
#
# Accessing page  51
#
# Accessing page  52
#
# Accessing page  53
#
# Accessing page  54
#
# Accessing page  55
#
# Accessing page  56
#
# Accessing page  57
#
# Accessing page  58
#
# Accessing page  59
#
# Accessing page  60
#
# Accessing page  61
#
# Accessing page  62
#
# Accessing page  63
#
# Accessing page  64
#
# Accessing page  65
#
# Accessing page  66
#
# Accessing page  67
#
# Accessing page  68
#
# Accessing page  69
#
# Accessing page  70
#
# Accessing page  71
#
# Accessing page  72
#
# Accessing page  73
#
# Accessing page  74
#
# Accessing page  75
#
# Accessing page  76
#
# Accessing page  77
#
# Accessing page  78
#
# Accessing page  79
#
# Accessing page  80
#
# Accessing page  81
#
# Accessing page  82
#
# Accessing page  83
#
# Accessing page  84
#
# Accessing page  85
#
# Accessing page  86
#
# Accessing page  87
#
# Accessing page  88
#
# Accessing page  89
#
# Accessing page  90
#
# Accessing page  91
#
# Accessing page  92
#
# Accessing page  93
#
# Accessing page  94
#
# Accessing page  95
#
# Accessing page  96
#
# Accessing page  97
#
# Accessing page  98
#
# Accessing page  99
#
# Accessing page  100
#
# Accessing page  101
#
# Accessing page  102
#
# Accessing page  103
#
# Accessing page  104
#
# Accessing page  105
#
# Accessing page  106
#
# Accessing page  107
#
# Accessing page  108
#
# Accessing page  109
#
# Accessing page  110
#
# Accessing page  111
#
# Accessing page  112
#
# Accessing page  113
#
# Accessing page  114
#
# Accessing page  115
#
# Accessing page  116
#
# Accessing page  117
#
# Accessing page  118
#
# Accessing page  119
#
# Accessing page  120
#
# Accessing page  121
#
# Accessing page  122
#
# Accessing page  123
#
# Accessing page  124
#
# Accessing page  125
#
# Accessing page  126
#
# Accessing page  127
#
# Accessing page  128
#
# Accessing page  129
#
# Accessing page  130
#
# Accessing page  131
#
# Accessing page  132
#
# Accessing page  133
#
# Accessing page  134
#
# Accessing page  135
#
# Accessing page  136
#
# Accessing page  137
#
# It's done now! You can look at the output csv file.
# There are  1046 jobs successfully extracted.
#                 job_id job_types    job_tag   post_time  \
# 0  jl_aefa77662d5bfc1d  fulltime  analytics  6 days ago
# 1  jl_719d91b70ae97f1c  fulltime  analytics   1 day ago
#
#                               job_title                              company  \
# 0  Head of Customer Insight & Analytics                           Rank Group
# 1       Head of Performance & Analytics  Barnet Clinical Commissioning Group
#
#                      salary    location no_of_review  \
# 0                       NaN  Maidenhead   18 reviews
# 1  £63,754 - £75,907 a year      Barnet          NaN
#
#                                          job_summary
# 0  � Responsible for leading a team of Analysts a...
# 1  Reporting to the Director of QIPP, Planning an...

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\zhixi\\Dropbox\\Postgraduate\\GA Data Immsersive\\Other jupyter notebook resources\\dsi-project-submission\\project-4_zhixin(jason)_wu'

# %%
df1=pd.read_csv('data/analyticsfulltime.csv')
df2=pd.read_csv('data/analyticspermanent.csv')

# %%
# test_df=pd.concat([df1,df2],ignore_index=False)
# test_df

# %%
# len(df1)

# %%
# len(df2)

# %%
# len(test_df)

# %%
df3=pd.read_csv('data/business intelligencefulltime.csv')
df4=pd.read_csv('data/business intelligencepermanent.csv')

# %%
df5=pd.read_csv('data/data analystfulltime.csv')
df6=pd.read_csv('data/data analystpermanent.csv')

# %%
df7=pd.read_csv('data/data engineerfulltime.csv')
df8=pd.read_csv('data/data engineerpermanent.csv')

# %%
df9=pd.read_csv('data/research scientistfulltime.csv')
df10=pd.read_csv('data/research scientistpermanent.csv')

# %%
final_df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])

# %%
final_df.drop_duplicates(inplace=True)

# %%
final_df.to_csv('combined.csv')

# %%
final_df.head()
# Out:
#    Unnamed: 0               job_id job_types    job_tag       post_time  \
# 0           0  jl_aefa77662d5bfc1d  fulltime  analytics      6 days ago
# 1           1  jl_719d91b70ae97f1c  fulltime  analytics       1 day ago
# 2           2  jl_d123655931ba246c  fulltime  analytics  43 minutes ago
# 3           3  jl_72f97ac8201bc2a2  fulltime  analytics    30+ days ago
# 4           4  jl_bbd4d855dae0fede  fulltime  analytics    19 hours ago
#
#                                            job_title  \
# 0               Head of Customer Insight & Analytics
# 1                    Head of Performance & Analytics
# 2  Insights & Analytics Intern | 8 week summer pl...
# 3                            Intern (Data Analytics)
# 4                           Data & Analytics Analyst
#
#                                company                    salary    location  \
# 0                           Rank Group                       NaN  Maidenhead
# 1  Barnet Clinical Commissioning Group  £63,754 - £75,907 a year      Barnet
# 2                             Asos.com                       NaN      London
# 3                   Keppel Corporation                       NaN      Keppel
# 4                                  RBS                       NaN     Belfast
#
#     no_of_review                                        job_summary
# 0     18 reviews  � Responsible for leading a team of Analysts a...
# 1            NaN  Reporting to the Director of QIPP, Planning an...
# 2    233 reviews  Developing a great understanding of modern ana...
# 3      3 reviews  Supports the Data Analytics team on project ba...
# 4  2,920 reviews  Strong analytic and problem solving abilities....

# %%
len(final_df)
# Out:
# 9742
